# %%
import pyautogui
import pyperclip
import time

# %%
pyautogui.PAUSE = 1

# %%
#1 - Entrar no sistema:
pyautogui.hotkey("ctrl", "t")
time.sleep(5)
pyperclip.copy("https://onedrive.live.com/?id=7D8C9E4713B2D5A9%2149078&cid=7D8C9E4713B2D5A9")
pyautogui.click(x=749, y=60)
time.sleep(2)
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("enter")
time.sleep(2)

#2 - Navegar até o local do relatório:
#pyautogui.click(x=1124, y=613)
#time.sleep(2)

#3 - Fazer o Download:
pyautogui.click(x=527, y=448)
pyautogui.click(x=656, y=182)
time.sleep(5)

# %%
#4 - Fazer o cálculo dos indicadores:
import pandas as pd

tabela = pd.read_excel(r"C://Users/L_SAR/Downloads/Vendas - Dez.xlsx")

display(tabela)
quantidade = tabela["Quantidade"].sum()
valorFinal = tabela["Valor Final"].sum()
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
print(quantidade)
print(valorFinal)
# Out:
# 15227
# 2917311

# %%
#5 - Entrar no e-mail:
pyautogui.hotkey("ctrl", "t")
time.sleep(5)
pyperclip.copy("https://outlook.live.com/mail/0/")
pyautogui.click(x=749, y=60)
time.sleep(2)
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("enter")
time.sleep(2)

#6 - Enviar e-mail:
pyautogui.click(x=240, y=179)
time.sleep(2)
pyperclip.copy("marcus.paulo@outlook.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")
pyperclip.copy("Relatório de vendas")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

texto = f"""
Presados, boa noite
faturamento de ontem foi de: R${valorFinal:,.2f}
a quantidade de produtos foi de: {quantidade:,}

Saudações, Lucas."""

pyperclip.copy(texto)
pyautogui.hotkey("ctrl", "v")

pyautogui.hotkey("ctrl", "enter")

# %%
#Pegar posição
#time.sleep(5)
#pyautogui.position()
